# %% [markdown]
# # Data Visualization

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import warnings

# %%
facts = pd.read_csv('PER_Ranking copy.csv', delimiter=',')

# %%
columns = facts.columns.tolist()
columns = columns[8:]
facts = facts.drop(columns, axis=1)
facts[['name','code']]=facts['Player'].str.split('\\', expand=True)

# %%
facts2 = pd.read_csv('all_seasons.csv', delimiter=',')

# %%
facts2 = facts2[facts2.season == '2017-18']

# %%
data= pd.merge(facts, facts2, left_on='name', right_on="player_name", how='left')

# %%
columns2 = data.columns.tolist()
columns3 = columns2[19:31]
data = data.drop(columns3, axis=1)

# %%
columns4=columns2[2:7]
data = data.drop(columns4, axis=1)
data.sort_values (by='college')
# Out:
#       Rk                       Player  PER▼               name       code  \
# 191  191         Tony Snell\snellto01   8.5         Tony Snell  snellto01
# 124  124     JaMychal Green\greenja01  14.0     JaMychal Green  greenja01
# 91    91    Lauri Markkanen\markkla01  15.6    Lauri Markkanen  markkla01
# 190  190    Stanley Johnson\johnsst04   9.0    Stanley Johnson  johnsst04
# 70    70       Aaron Gordon\gordoaa01  16.5       Aaron Gordon  gordoaa01
# ..   ...                          ...   ...                ...        ...
# 96    96   Tomáš Satoranský\satorto01  15.4   Tomáš Satoranský  satorto01
# 104  104     Ersan İlyasova\ilyaser01  14.9     Ersan İlyasova  ilyaser01
# 125  125   Bojan Bogdanović\bogdabo02  13.9   Bojan Bogdanović  bogdabo02
# 133  133  Bogdan Bogdanović\bogdabo01  13.5  Bogdan Bogdanović  bogdabo01
# 192  192         J.R. Smith\smithjr01   8.4         J.R. Smith  smithjr01
#
#      Unnamed: 0      player_name team_abbreviation   age  player_height  \
# ...

# %%
PERnumbers= data[["PER▼", "college"]].groupby(by="college").sum()

# %%
results= PERnumbers.sort_values(by='PER▼',ascending=False).head(10)

# %%
results
# Out:
#                  PER▼
# college
# None            351.3
# Kentucky        226.2
# UCLA            123.9
# Wake Forest     102.3
# Texas           102.3
# Duke             92.4
# North Carolina   92.1
# Arizona          81.7
# Connecticut      74.7
# Kansas           72.8

# %%
results.plot(kind='bar',figsize=(10,10),xlabel='College',ylabel='Total PER Score',title='Total PER Score Per College, 2017-18 Season', legend=True, colormap='flag')
# Out:
# <AxesSubplot:title={'center':'Total PER Score Per College, 2017-18 Season'}, xlabel='College', ylabel='Total PER Score'>

# %%
#this graph shows the total PER score for each college during the 2017-18 Season
#the None section includes all international players and individuals who did not attend college
#I chose a bar graph because I thought it was the best way to compare each school's total PER score

# %% [markdown]
# Select a dataset we have used in class (or outside of class).
#
# Generate a plot that you feel visualizes the data is an interesting way. Your plot should have the following elements:
#
# >1) Title
# >2) Legend
# >3) Axes or other Labels
# >4) Color
# >5) 1 sentence description of what your plot shows
# >6) Brief description of why you chose to make the plot the way you did.
#
# You may use pandas, matplotlib, or seaborn.
#
# Upload a pdf of the plot to Canvas.
